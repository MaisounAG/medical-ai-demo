# %%
#Read the data in pandas format
import pandas as pd
with open ('heart.csv') as file:
    df=pd.read_csv('heart.csv')

print (df)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
#Display the first five rows in the dataset
print (df.head())
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
#Display the shape of the dataset
print (df.shape)
# Out:
# (918, 12)

# %%
#Print information about the dataframe
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# None

# %%
#Check if there is any null values in the dataset and count them
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
#Print statistical information about each column in the dataset, including the count, mean, std, min, and max
print(df.describe().count)
# Out:
# <bound method DataFrame.count of               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000  >

# %%
#Print the correlation table between the columns in the dataset
print (df['Age'].corr(df['HeartDisease']))
print (df['Cholesterol'].corr(df['HeartDisease']))
print (df['MaxHR'].corr(df['HeartDisease']))
# Out:
# 0.28203850581899736
# -0.2327406389270117
# -0.40042076946319033

# %%
#Example 1: Counting Occurrences of Each Chest Pain Type
print(df['Age'].values)
df['ChestPainType'].value_counts()
# Out:
# [40 49 37 48 54 39 45 54 37 48 37 58 39 49 42 54 38 43 60 36 43 44 49 44
#  40 36 53 52 53 51 53 56 54 41 43 32 65 41 48 48 54 54 35 52 43 59 37 50
#  36 41 50 47 45 41 52 51 31 58 54 52 49 43 45 46 50 37 45 32 52 44 57 44
#  52 44 55 46 32 35 52 49 55 54 63 52 56 66 65 53 43 55 49 39 52 48 39 58
#  43 39 56 41 65 51 40 40 46 57 48 34 50 39 59 57 47 38 49 33 38 59 35 34
#  47 52 46 58 58 54 34 48 54 42 38 46 56 56 61 49 43 39 54 43 52 50 47 53
#  56 39 42 43 50 54 39 48 40 55 41 56 38 49 44 54 59 49 47 42 52 46 50 48
#  58 58 29 40 53 49 52 43 54 59 37 46 52 51 52 46 54 58 58 41 50 53 46 50
#  48 45 41 62 49 42 53 57 47 46 42 31 56 50 35 35 28 54 48 50 56 56 47 30
#  39 54 55 29 46 51 48 33 55 50 53 38 41 37 37 40 38 41 54 39 41 55 48 48
#  55 54 55 43 48 54 54 48 45 49 44 48 61 62 55 53 55 36 51 55 46 54 46 59
#  47 54 52 34 54 47 45 32 55 55 45 59 51 52 57 54 60 49 51 55 42 51 59 53
#  48 36 48 47 53 65 32 61 50 57 51 47 60 55 53 62 51 51 55 53 58 57 65 60
# ...

# %%
#Example 2: Creating a List of Patients with High Cholesterol
print(df.loc[df['Cholesterol']>200])
print(list(df.loc[df['Cholesterol']>200]))
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 5     39   M           NAP        120          339          0     Normal
# 6     45   F           ATA        130          237          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 905   67   M           NAP        152          212          0        LVH
# 906   55   F           ATA        132          342          0     Normal
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 916   57   F           ATA        130          236          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
#Example 3: Calculating Average Max Heart Rate for Male and Female Patients
average_max_hr = df.groupby('Sex')['MaxHR'].mean()
print(f"Average Max Heart Rate for Male Patients: {average_max_hr['M']}")
print(f"Average Max Heart Rate for Female Patients: {average_max_hr['F']}")
# Out:
# Average Max Heart Rate for Male Patients: 134.32551724137932
# Average Max Heart Rate for Female Patients: 146.13989637305698

# %%
#Example 4: Finding the Patient with the Highest Cholesterol
df.loc[df['Cholesterol'].max()]
# Out:
# Age                   74
# Sex                    M
# ChestPainType        ASY
# RestingBP            155
# Cholesterol          310
# FastingBS              0
# RestingECG        Normal
# MaxHR                112
# ExerciseAngina         Y
# Oldpeak              1.5
# ST_Slope            Down
# HeartDisease           1
# Name: 603, dtype: object

# %%
#Example 5: Calculating the Percentage of Patients with Heart Disease
# Calculate the number of patients with heart disease
heart_disease_patients = df[df['HeartDisease'] == 1].shape[0]
# Calculate the total number of patients
total_patients = df.shape[0]
# Calculate the percentage of patients with heart disease
print(f"Percentage of patients with heart disease: {percentage_heart_disease:.2f}%")
# Out:
# Percentage of patients with heart disease: 55.34%
